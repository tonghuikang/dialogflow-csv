# %%
import pandas as pd
import json
import time
import os

# %%
# generate ID
import random

def generate_ID():
    c = ["".join([random.choice('01234567890abcdef') for _ in range(4)]) 
         for _ in range(8)]
    return c[0]+c[1]+"-"+c[2]+"-"+c[3]+"-"+c[4]+"-"+c[5]+c[6]+c[7]

generate_ID()
# Out:
# 'da60b42d-4aa5-59b9-ecb6-a13aa430968a'

# %%
# copy template
os.system("rm -r template")
os.system("cp -r stencil template")
# Out:
# 0

# %%
df = pd.read_csv('template.csv', header=0)
df
# Out:
#     Unnamed: 0             INTENT_NAME       INPUT_CONTEXT Unnamed: 3  \
# 0            0  Default Welcome Intent                 NaN        NaN
# 1            1    consideration - none       consideration        NaN
# 2            2        consideration-no  past-consideration        NaN
# 3            3       consideration-yes  past-consideration        NaN
# 4            4           consideration       consideration        NaN
# 5            5         contract matter                 NaN        NaN
# 6            6         criminal matter                 NaN        NaN
# 7            7          divorce matter                 NaN        NaN
# 8            8             make coffee             thirsty        aaa
# 9            9               make love                rich        NaN
# 10          10              make money                 NaN        NaN
# 11          11                make tea             thirsty        NaN
# 12          12            make trouble                 NaN        NaN
# 13          13              make water                 NaN        NaN
# 14          14                 promise            contract        NaN
#
#    Unnamed: 4         OUTPUT_CONTEXT Unnamed: 6  Unnamed: 7  \
# 0         NaN                    NaN        NaN         NaN
# 1         NaN                    NaN        NaN         NaN
# 2         NaN                    NaN        NaN         NaN
# 3         NaN                    NaN        NaN         NaN
# 4         NaN  2, past-consideration        NaN         NaN
# 5         NaN            2, contract        NaN         NaN
# 6         NaN                    NaN        NaN         NaN
# 7         NaN                    NaN        NaN         NaN
# 8         bbb             0, thirsty   1, caffy         NaN
# 9         NaN                    NaN        NaN         NaN
# 10        NaN             2, thirsty    1, rich         NaN
# 11        NaN               10, woke        NaN         NaN
# 12        NaN                    NaN        NaN         NaN
# 13        NaN                    NaN        NaN         NaN
# 14        NaN       2, consideration        NaN         NaN
#
#                      USER_SAYS                 Unnamed: 9  \
# 0         just going to say hi                       heya
# 1                      Nothing                        NaN
# 2                           No                        NaN
# 3                          Yes                        NaN
# 4   I performed for my friend.                        NaN
# 5        my friend didn't pay   my employer didn't pay me
# 6        my husband is in jail                        NaN
# 7     my husband cheated on me                        NaN
# 8                i want coffee            lim kopi ai mai
# 9                  i want love                        NaN
# 10                i want money                  bo lui ah
# 11                  i want tea                  lim tehsi
# 12                kua simi kua               le kua si mi
# 13                i want water                        NaN
# 14    I was promised $50/night     I was promised a house
#
#                  ...                 Unnamed: 19  Unnamed: 20 Unnamed: 21  \
# 0                ...                 I greet you  hello again          hi
# 1                ...                         NaN          NaN         NaN
# 2                ...                         NaN          NaN         NaN
# 3                ...                         NaN          NaN         NaN
# 4                ...                         NaN          NaN         NaN
# 5                ...                         NaN          NaN         NaN
# 6                ...                         NaN          NaN         NaN
# 7                ...                         NaN          NaN         NaN
# 8                ...                         NaN          NaN         NaN
# 9                ...                         NaN          NaN         NaN
# 10               ...                         NaN          NaN         NaN
# 11               ...                         NaN          NaN         NaN
# 12               ...                         NaN          NaN         NaN
# 13               ...                         NaN          NaN         NaN
# 14               ...                         NaN          NaN         NaN
#
#     Unnamed: 22 Unnamed: 23  \
# 0   hello there  a good day
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# 5           NaN         NaN
# 6           NaN         NaN
# 7           NaN         NaN
# 8           NaN         NaN
# 9           NaN         NaN
# 10          NaN         NaN
# 11          NaN         NaN
# 12          NaN         NaN
# 13          NaN         NaN
# 14          NaN         NaN
#
#                                             RESPONSES  \
# 0                              Hi! How are you doing?
# 1   It seems that you did not offer anything for t...
# 2   You may have a case against (person). Please m...
# 3   Past consideration isn't considered a consider...
# 4   It seems like there is an exchange. However we...
# 5                              What were you promised
# 6           Out of scope please refer to another firm
# 7   This is out of scope, please refer another web...
# 8                                 half full drink up!
# 9                                                  <3
# 10                                            huat ah
# 11                                       slowly drink
# 12                                      come fight la
# 13                                                NaN
# 14  You were promised (echo the thing). What did y...
#
#                    Unnamed: 25                             Unnamed: 26  \
# 0   Hello! How can I help you?  Good day! What can I do for you today?
# 1                          NaN                                     NaN
# 2                          NaN                                     NaN
# 3                          NaN                                     NaN
# 4                          NaN                                     NaN
# 5                          NaN                                     NaN
# 6                          NaN                                     NaN
# 7                          NaN                                     NaN
# 8             bo ta bo lam pah                             bottoms up!
# 9                          NaN                                     NaN
# 10                         NaN                                     NaN
# 11              take your time                                     NaN
# 12                         NaN                                     NaN
# 13                         NaN                                     NaN
# 14                         NaN                                     NaN
#
#                      Unnamed: 27                      Unnamed: 28
# 0   Greetings! How can I assist?                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# 5                            NaN                              NaN
# 6                            NaN                              NaN
# 7                            NaN                              NaN
# 8            drink till you drop  now converting coffee into code
# 9                            NaN                              NaN
# 10                           NaN                              NaN
# 11                           NaN                              NaN
# 12                           NaN                              NaN
# 13                           NaN                              NaN
# 14                           NaN                              NaN
#
# [15 rows x 29 columns]

# %%
# get column number for manipulation next
col_num_INTENT_NAME = df.columns.get_loc("INTENT_NAME")
col_num_IN = df.columns.get_loc("INPUT_CONTEXT")
col_num_OUT = df.columns.get_loc("OUTPUT_CONTEXT")
col_num_USER = df.columns.get_loc("USER_SAYS")
col_num_RESP = df.columns.get_loc("RESPONSES")
col_num_total = len(df.columns)

# %%
def rm_nan(list_of_list):
    '''remove nan from list of list'''
    return [[x for x in list_ if x == x] for list_ in list_of_list]
    
df['INPUT_CONTEXT_L'] = rm_nan(df.iloc[:,col_num_IN:col_num_OUT].values.tolist())
df['OUTPUT_CONTEXT_L'] = rm_nan(df.iloc[:,col_num_OUT:col_num_USER].values.tolist())
df['USER_SAYS_L'] = rm_nan(df.iloc[:,col_num_USER:col_num_RESP].values.tolist())
df['RESPONSES_L'] = rm_nan(df.iloc[:,col_num_RESP:col_num_total].values.tolist())

# %%
# combine columns, ignoring nan
# https://stackoverflow.com/questions/45787782/combine-multiple-columns-in-pandas-excluding-nans
# df['INPUT_CONTEXT_L'] = df.iloc[:,col_num_IN:col_num_OUT].apply(lambda x: list(x.dropna()), axis=1).values.tolist()
# df['OUTPUT_CONTEXT_L'] = df.iloc[:,col_num_OUT:col_num_USER].apply(lambda x: list(x.dropna()), axis=1).values.tolist()
# df['USER_SAYS_L'] = df.iloc[:,col_num_USER:col_num_RESP].apply(lambda x: list(x.dropna()), axis=1).values.tolist()
# df['RESPONSES_L'] = df.iloc[:,col_num_RESP:col_num_total].apply(lambda x: list(x.dropna()), axis=1).values.tolist()
# I don't understand why line 1 works but line 3 and 4 don't work. WTF.

# %%
df
# Out:
#     Unnamed: 0             INTENT_NAME       INPUT_CONTEXT Unnamed: 3  \
# 0            0  Default Welcome Intent                 NaN        NaN
# 1            1    consideration - none       consideration        NaN
# 2            2        consideration-no  past-consideration        NaN
# 3            3       consideration-yes  past-consideration        NaN
# 4            4           consideration       consideration        NaN
# 5            5         contract matter                 NaN        NaN
# 6            6         criminal matter                 NaN        NaN
# 7            7          divorce matter                 NaN        NaN
# 8            8             make coffee             thirsty        aaa
# 9            9               make love                rich        NaN
# 10          10              make money                 NaN        NaN
# 11          11                make tea             thirsty        NaN
# 12          12            make trouble                 NaN        NaN
# 13          13              make water                 NaN        NaN
# 14          14                 promise            contract        NaN
#
#    Unnamed: 4         OUTPUT_CONTEXT Unnamed: 6  Unnamed: 7  \
# 0         NaN                    NaN        NaN         NaN
# 1         NaN                    NaN        NaN         NaN
# 2         NaN                    NaN        NaN         NaN
# 3         NaN                    NaN        NaN         NaN
# 4         NaN  2, past-consideration        NaN         NaN
# 5         NaN            2, contract        NaN         NaN
# 6         NaN                    NaN        NaN         NaN
# 7         NaN                    NaN        NaN         NaN
# 8         bbb             0, thirsty   1, caffy         NaN
# 9         NaN                    NaN        NaN         NaN
# 10        NaN             2, thirsty    1, rich         NaN
# 11        NaN               10, woke        NaN         NaN
# 12        NaN                    NaN        NaN         NaN
# 13        NaN                    NaN        NaN         NaN
# 14        NaN       2, consideration        NaN         NaN
#
#                      USER_SAYS                 Unnamed: 9  \
# 0         just going to say hi                       heya
# 1                      Nothing                        NaN
# 2                           No                        NaN
# 3                          Yes                        NaN
# 4   I performed for my friend.                        NaN
# 5        my friend didn't pay   my employer didn't pay me
# 6        my husband is in jail                        NaN
# 7     my husband cheated on me                        NaN
# 8                i want coffee            lim kopi ai mai
# 9                  i want love                        NaN
# 10                i want money                  bo lui ah
# 11                  i want tea                  lim tehsi
# 12                kua simi kua               le kua si mi
# 13                i want water                        NaN
# 14    I was promised $50/night     I was promised a house
#
#                           ...                         Unnamed: 23  \
# 0                         ...                          a good day
# 1                         ...                                 NaN
# 2                         ...                                 NaN
# 3                         ...                                 NaN
# 4                         ...                                 NaN
# 5                         ...                                 NaN
# 6                         ...                                 NaN
# 7                         ...                                 NaN
# 8                         ...                                 NaN
# 9                         ...                                 NaN
# 10                        ...                                 NaN
# 11                        ...                                 NaN
# 12                        ...                                 NaN
# 13                        ...                                 NaN
# 14                        ...                                 NaN
#
#                                             RESPONSES  \
# 0                              Hi! How are you doing?
# 1   It seems that you did not offer anything for t...
# 2   You may have a case against (person). Please m...
# 3   Past consideration isn't considered a consider...
# 4   It seems like there is an exchange. However we...
# 5                              What were you promised
# 6           Out of scope please refer to another firm
# 7   This is out of scope, please refer another web...
# 8                                 half full drink up!
# 9                                                  <3
# 10                                            huat ah
# 11                                       slowly drink
# 12                                      come fight la
# 13                                                NaN
# 14  You were promised (echo the thing). What did y...
#
#                    Unnamed: 25                             Unnamed: 26  \
# 0   Hello! How can I help you?  Good day! What can I do for you today?
# 1                          NaN                                     NaN
# 2                          NaN                                     NaN
# 3                          NaN                                     NaN
# 4                          NaN                                     NaN
# 5                          NaN                                     NaN
# 6                          NaN                                     NaN
# 7                          NaN                                     NaN
# 8             bo ta bo lam pah                             bottoms up!
# 9                          NaN                                     NaN
# 10                         NaN                                     NaN
# 11              take your time                                     NaN
# 12                         NaN                                     NaN
# 13                         NaN                                     NaN
# 14                         NaN                                     NaN
#
#                      Unnamed: 27                      Unnamed: 28  \
# 0   Greetings! How can I assist?                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# 5                            NaN                              NaN
# 6                            NaN                              NaN
# 7                            NaN                              NaN
# 8            drink till you drop  now converting coffee into code
# 9                            NaN                              NaN
# 10                           NaN                              NaN
# 11                           NaN                              NaN
# 12                           NaN                              NaN
# 13                           NaN                              NaN
# 14                           NaN                              NaN
#
#          INPUT_CONTEXT_L         OUTPUT_CONTEXT_L  \
# 0                     []                       []
# 1        [consideration]                       []
# 2   [past-consideration]                       []
# 3   [past-consideration]                       []
# 4        [consideration]  [2, past-consideration]
# 5                     []            [2, contract]
# 6                     []                       []
# 7                     []                       []
# 8    [thirsty, aaa, bbb]   [0, thirsty, 1, caffy]
# 9                 [rich]                       []
# 10                    []    [2, thirsty, 1, rich]
# 11             [thirsty]               [10, woke]
# 12                    []                       []
# 13                    []                       []
# 14            [contract]       [2, consideration]
#
#                                           USER_SAYS_L  \
# 0   [just going to say hi, heya, hello hi, howdy, ...
# 1                                           [Nothing]
# 2                                                [No]
# 3                                               [Yes]
# 4                        [I performed for my friend.]
# 5   [my friend didn't pay , my employer didn't pay...
# 6                             [my husband is in jail]
# 7                          [my husband cheated on me]
# 8   [i want coffee, lim kopi ai mai, kopi siu dai ...
# 9                                       [i want love]
# 10                          [i want money, bo lui ah]
# 11                            [i want tea, lim tehsi]
# 12                       [kua simi kua, le kua si mi]
# 13                                     [i want water]
# 14  [I was promised $50/night, I was promised a ho...
#
#                                           RESPONSES_L
# 0   [Hi! How are you doing?, Hello! How can I help...
# 1   [It seems that you did not offer anything for ...
# 2   [You may have a case against (person). Please ...
# 3   [Past consideration isn't considered a conside...
# 4   [It seems like there is an exchange. However w...
# 5                            [What were you promised]
# 6         [Out of scope please refer to another firm]
# 7   [This is out of scope, please refer another we...
# 8   [half full drink up!, bo ta bo lam pah, bottom...
# 9                                                [<3]
# 10                                          [huat ah]
# 11                     [slowly drink, take your time]
# 12                                    [come fight la]
# 13                                                 []
# 14  [You were promised (echo the thing). What did ...
#
# [15 rows x 33 columns]

# %%
# # for line in rows of excel
# intent_df_row = None 
for index, row in df.iterrows():  # CURRENTLY ONLY PROCESSING ONE ROW
    intent_df_row = row
#     break

# %%
intent_name = intent_df_row['INTENT_NAME']
input_contexts = intent_df_row['INPUT_CONTEXT_L']
output_contexts = [[y.strip() for y in x.split(',')]
                   for x in intent_df_row['OUTPUT_CONTEXT_L']]
training_phrases = intent_df_row['USER_SAYS_L']
responses = intent_df_row['RESPONSES_L']

# %%
# define a list/dictionary for {intent_name}.json
intent_jsonfile = {}
intent_jsonfile["id"] = generate_ID() # to randomly generate
intent_jsonfile["name"] = intent_name
intent_jsonfile["auto"] = True # will change to lowercase when converted to jsonfile
intent_jsonfile["contexts"] = input_contexts

intent_jsonfile_responses = {}
intent_jsonfile_responses["resetContexts"] = False
intent_jsonfile_responses["affectedContexts"] = []

for output_context in output_contexts:
    affectedContext = {}
    affectedContext["name"] = output_context[1]
    affectedContext["parameters"] = {}
    affectedContext["lifespan"] = output_context[0]
    intent_jsonfile_responses["affectedContexts"].append(affectedContext)
    
intent_jsonfile_responses["parameters"] = []
intent_jsonfile_responses["messages"] = []  # probably allow for list of messages?
message = {}
message["type"] = 0
message["lang"] = "en"
message["speech"] = responses
intent_jsonfile_responses["messages"].append(message)

intent_jsonfile_responses["defaultResponsePlatforms"] = []
intent_jsonfile_responses["speech"] = []
intent_jsonfile["responses"] = [intent_jsonfile_responses]  #

intent_jsonfile["priority"] = 500000
intent_jsonfile["webhookUsed"] = False
intent_jsonfile["webhookForSlotFilling"] = False
intent_jsonfile["lastUpdate"] = int(time.time())
intent_jsonfile["fallbackIntent"] =  False
intent_jsonfile["events"] = []

# %%
print(json.dumps(intent_jsonfile))
# Out:
# {"id": "f20e55ab-603f-096a-407d-642716f0c000", "name": "promise", "auto": true, "contexts": ["contract"], "responses": [{"resetContexts": false, "affectedContexts": [{"name": "consideration", "parameters": {}, "lifespan": "2"}], "parameters": [], "messages": [{"type": 0, "lang": "en", "speech": ["You were promised (echo the thing). What did you need to do for the promise?"]}], "defaultResponsePlatforms": [], "speech": []}], "priority": 500000, "webhookUsed": false, "webhookForSlotFilling": false, "lastUpdate": 1557130355, "fallbackIntent": false, "events": []}

# %% [markdown]
# {
#   "id": "f60c8a1f-2911-448b-90c6-facd27259ed0",
#   "name": "training phrases test",
#   "auto": true,
#   "contexts": [
#     "inputcontexttest"
#   ],
#   "responses": [
#     {
#       "resetContexts": false,
#       "affectedContexts": [
#         {
#           "name": "outputcontexttest",
#           "parameters": {},
#           "lifespan": 999
#         }
#       ],
#       "parameters": [],
#       "messages": [
#         {
#           "type": 0,
#           "lang": "en",
#           "speech": [
#             "sample response one",
#             "sample response two",
#             "sample response three"
#           ]
#         }
#       ],
#       "defaultResponsePlatforms": {},
#       "speech": []
#     }
#   ],
#   "priority": 500000,
#   "webhookUsed": false,
#   "webhookForSlotFilling": false,
#   "lastUpdate": 1548814094,
#   "fallbackIntent": false,
#   "events": []
# }

# %%
# define a list/dictionary for {intent_usersays_name}.json
intent_usersays_jsonfile = []
for training_phrase in training_phrases:
    user_say = {}
    user_say["id"] = generate_ID()
    user_say["data"] = []  # no entities for now and the near future
    snippet = {}
    snippet["text"] = training_phrase
    snippet["userDefined"] = False
    user_say["data"] = [snippet]
    
    user_say["isTemplate"] = False
    user_say["count"] = 0
    user_say["updated"] = int(time.time())
    intent_usersays_jsonfile.append(user_say)

# %%
print(json.dumps(intent_usersays_jsonfile))
# Out:
# [{"id": "9ed03198-1e1a-e1f6-bd09-770c138bc72a", "data": [{"text": "I was promised $50/night", "userDefined": false}], "isTemplate": false, "count": 0, "updated": 1557130356}, {"id": "eb0c0879-dff2-a217-d861-7c5211f2ffbd", "data": [{"text": "I was promised a house", "userDefined": false}], "isTemplate": false, "count": 0, "updated": 1557130356}]

# %% [markdown]
# [
#   {
#     "id": "f65bbd35-97d6-4862-bd56-5e360dbe7d08",
#     "data": [
#       {
#         "text": "training phrase ",
#         "userDefined": false
#       },
#       {
#         "text": "three",
#         "meta": "@sys.ignore",
#         "userDefined": false
#       }
#     ],
#     "isTemplate": false,
#     "count": 0,
#     "updated": 1548814041
#   }
# ]

# %%
with open('template/intents/{}.json'.format(intent_name), 'w') as outfile:
    json.dump(intent_jsonfile, outfile)

with open('template/intents/{}_usersays_en.json'.format(intent_name), 'w') as outfile:
    json.dump(intent_usersays_jsonfile, outfile)

# then process the next intent

# %%
# "project": "newagent-fcefe" may be an issue
agent_json = '''{
  "description": "",
  "language": "en",
  "disableInteractionLogs": false,
  "disableStackdriverLogs": true,
  "googleAssistant": {
    "googleAssistantCompatible": false,
    "project": "newagent-fcefe",
    "welcomeIntentSignInRequired": false,
    "startIntents": [],
    "systemIntents": [],
    "endIntentIds": [],
    "oAuthLinking": {
      "required": false,
      "grantType": "AUTH_CODE_GRANT"
    },
    "voiceType": "MALE_1",
    "capabilities": [],
    "protocolVersion": "V2",
    "isDeviceAgent": false
  },
  "defaultTimezone": "Asia/Hong_Kong",
  "webhook": {
    "available": false,
    "useForDomains": false,
    "cloudFunctionsEnabled": false,
    "cloudFunctionsInitialized": false
  },
  "isPrivate": true,
  "customClassifierMode": "use.after",
  "mlMinConfidence": 0.3,
  "supportedLanguages": [],
  "onePlatformApiVersion": "v2",
  "analyzeQueryTextSentiment": false,
  "enabledKnowledgeBaseNames": [],
  "knowledgeServiceConfidenceAdjustment": -0.4,
  "dialogBuilderMode": false
}'''

# %%
os.system("rm template.zip")
os.system("zip -r template.zip template -x *.DS_Store")
# Out:
# 0

# %%
# convert this notebook into a python script
# and then remove the last few lines
get_ipython().system('jupyter nbconvert --to script csv-to-df-one-intent.ipynb')
# !for i in {1..10}; do sed -i '' -e '$ d' csv-to-df-one-intent.py; done
